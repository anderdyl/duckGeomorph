# %%
from getdatatestbed import getDataFRF
import datetime as DT 
import numpy as np
from matplotlib import pyplot as plt 
# %matplotlib inline
import netCDF4 as nc

# %% [markdown]
# This script is an example for mike forte to evaluate and look at the regression through time of the entire FRF property.  This as it stands right now is only on the North side, it does a gridded evolution through time of the survey data.  Things to notice are the surveys changed around 1995 (dunes stopped being captured, and profiles lengthened).  the cross-shore migration of sandbars from the shoreline to about 400m before they dissapear
#
# # TODO
# - do the same thing on the south side
# - do a subtraction of the North and south profiles to highlight the difference (if any) between most offshore profiles. tip: use midpoint normalize to center the RdBu colormap on zero when doing the diffence plot
#
# # possible problems
# - time as its rounded right now seems to round part of the surveys in to one day and part into another day. this causes some of the data to be excluded om the analysis, it should be more throughly added

# %%
def roundTime(dt=None, roundTo=60):
   """Round a datetime object to any time lapse in seconds
   dt : datetime.datetime object, default now.
   roundTo : Closest number of seconds to round to, default 1 minute.
   Author: Thierry Husson 2012 - Use it as you want but don't blame me.
   """
   if dt == None : dt = DT.datetime.now()
   seconds = (dt.replace(tzinfo=None) - dt.min).seconds
   rounding = (seconds+roundTo/2) // roundTo * roundTo
   return dt + DT.timedelta(0,rounding-seconds,-dt.microsecond)

import matplotlib.colors as colors

class MidpointNormalize(colors.Normalize):
    """	Normalise the colorbar so that diverging bars work there way either side from a prescribed midpoint value)

    e.g. im=ax1.imshow(array, norm=MidpointNormalize(midpoint=0.,vmin=-100, vmax=100))

    Examples:
        elev_min=-1000
        elev_max=3000
        mid_val=0

        plt.imshow(ras, cmap=cmap, clim=(elev_min, elev_max), norm=MidpointNormalize(midpoint=mid_val,vmin=elev_min, vmax=elev_max))
        plt.colorbar()
        plt.show()
    """

    def __init__(self, vmin=None, vmax=None, midpoint=None, clip=False):
        self.midpoint = midpoint
        colors.Normalize.__init__(self, vmin, vmax, clip)

    def __call__(self, value, clip=None):
        # I'm ignoring masked values and all kinds of edge cases to make a
        # simple example...
        x, y = [self.vmin, self.midpoint, self.vmax], [0, 0.5, 1]
        return np.ma.masked_array(np.interp(value, x, y), np.isnan(value))

# %%
go  = getDataFRF.getObs(DT.datetime(1900,1,1), DT.datetime(2019,12,1))
survey = go.getBathyTransectFromNC(forceReturnAll=True)
print(survey.keys())
# what are my north and south lines of interest
NorthIdx = survey['profileNumber'] == 1097
southIdx = survey['profileNumber'] == 1
crossShoreMax = 1000   # how far do we want to look in cross-shore
# Out:
# dict_keys(['xFRF', 'yFRF', 'elevation', 'epochtime', 'time', 'lat', 'lon', 'northing', 'easting', 'profileNumber', 'surveyNumber', 'Ellipsoid'])

# %%
# isolate data for Northside line only 
timesNorth = survey['time'][NorthIdx]
xFRFNorth = survey['xFRF'][NorthIdx]
elevationNorth = survey['elevation'][NorthIdx]
surveyNumberNorth = survey['surveyNumber'][NorthIdx]
epochTimesNorth = survey['epochtime'][NorthIdx]
# UniqueSurveyNumbersNorth = np.unique(surveyNumberNorth)
timesNorth = [roundTime(t, roundTo=60*60*24) for t in timesNorth]  #round to nearest Day
epochTimesNorth = nc.date2num(timesNorth, 'seconds since 1970-01-01')
# quick plot to see what we're looking at 
plt.plot(xFRFNorth, elevationNorth,'.')
plt.xlim([0, crossShoreMax])
plt.ylim([-16, 8])
# Out:
# (-16, 8)

# %%
# now grid data in cross shore
from scipy import interpolate
minPoints4Survey = 10
xOut = np.arange(0,1800)
tOut = np.unique(epochTimesNorth)
#how many unique surveys do i have??
zOutNorth = np.ma.masked_all((tOut.shape[0], xOut.shape[0])) # initalize masked array all values True
for ss, surveyTime in enumerate(tOut):  # ss is index of value surveyNum
    idxSurveyPoints = epochTimesNorth == surveyTime
    print('{} survey points in survey on {}'.format(np.sum(idxSurveyPoints), nc.num2date(surveyTime, 'seconds since 1970-01-01')))
    print('Mean elevations {:.2f}'.format(elevationNorth[idxSurveyPoints].mean()))
    if idxSurveyPoints.sum() > minPoints4Survey:  # sometimes there's not enough points on a day (i don't know why)
        tempf = interpolate.interp1d(xFRFNorth[idxSurveyPoints], elevationNorth[idxSurveyPoints],
                                     bounds_error=False, kind='linear', fill_value='nan')
        zOutNorth[ss] = tempf(xOut)
#     else:
#         print('  deleted ss{}'.format(ss))
#         tOut=np.delete(tOut,ss)
# Out:
# 37 survey points in survey on 1981-10-17 00:00:00
# Mean elevations -1.28
# 45 survey points in survey on 1981-10-27 00:00:00
# Mean elevations -2.61
# 43 survey points in survey on 1981-12-01 00:00:00
# Mean elevations -2.44
# 44 survey points in survey on 1981-12-17 00:00:00
# Mean elevations -2.57
# 48 survey points in survey on 1982-01-06 00:00:00
# Mean elevations -2.30
# 45 survey points in survey on 1982-01-21 00:00:00
# Mean elevations -2.64
# 51 survey points in survey on 1982-01-29 00:00:00
# Mean elevations -3.08
# 1 survey points in survey on 1982-02-09 00:00:00
# Mean elevations 5.86
# 39 survey points in survey on 1982-02-10 00:00:00
# Mean elevations -2.83
# 38 survey points in survey on 1982-02-17 00:00:00
# Mean elevations -2.43
# 42 survey points in survey on 1982-03-03 00:00:00
# Mean elevations -3.15
# 42 survey points in survey on 1982-03-31 00:00:00
# Mean elevations -3.09
# 35 survey points in survey on 1982-04-15 00:00:00
# Mean elevations -2.75
# 1 survey points in survey on 1982-04-21 00:00:00
# Mean elevations 5.70
# 40 survey points in survey on 1982-04-22 00:00:00
# Mean elevations -3.00
# 36 survey points in survey on 1982-05-04 00:00:00
# Mean elevations -3.16
# 42 survey points in survey on 1982-05-18 00:00:00
# Mean elevations -2.59
# 2 survey points in survey on 1982-06-02 00:00:00
# Mean elevations 5.83
# 41 survey points in survey on 1982-06-03 00:00:00
# Mean elevations -3.02
# 40 survey points in survey on 1982-06-17 00:00:00
# Mean elevations -2.68
# 46 survey points in survey on 1982-07-02 00:00:00
# Mean elevations -2.93
# 34 survey points in survey on 1982-07-27 00:00:00
# Mean elevations -3.12
# 36 survey points in survey on 1982-08-11 00:00:00
# Mean elevations -2.83
# 1 survey points in survey on 1982-08-24 00:00:00
# Mean elevations 5.69
# 35 survey points in survey on 1982-08-25 00:00:00
# Mean elevations -3.26
# 1 survey points in survey on 1982-09-01 00:00:00
# Mean elevations 5.89
# 37 survey points in survey on 1982-09-02 00:00:00
# Mean elevations -3.78
# 48 survey points in survey on 1982-10-28 00:00:00
# Mean elevations -2.70
# 4 survey points in survey on 1982-11-08 00:00:00
# Mean elevations 4.71
# 38 survey points in survey on 1982-11-09 00:00:00
# Mean elevations -4.49
# 1 survey points in survey on 1982-12-06 00:00:00
# Mean elevations 5.94
# 32 survey points in survey on 1982-12-07 00:00:00
# Mean elevations -2.78
# 40 survey points in survey on 1982-12-15 00:00:00
# Mean elevations -2.84
# 1 survey points in survey on 1982-12-22 00:00:00
# Mean elevations 5.94
# 47 survey points in survey on 1982-12-23 00:00:00
# Mean elevations -2.99
# 5 survey points in survey on 1983-01-14 00:00:00
# Mean elevations -7.92
# 2 survey points in survey on 1983-01-24 00:00:00
# Mean elevations 5.87
# 88 survey points in survey on 1983-01-25 00:00:00
# Mean elevations -3.47
# 40 survey points in survey on 1983-01-31 00:00:00
# Mean elevations -5.09
# 1 survey points in survey on 1983-02-08 00:00:00
# Mean elevations 5.94
# 31 survey points in survey on 1983-02-09 00:00:00
# Mean elevations -2.61
# 38 survey points in survey on 1983-02-25 00:00:00
# Mean elevations -2.50
# 38 survey points in survey on 1983-03-23 00:00:00
# Mean elevations -3.05
# 38 survey points in survey on 1983-03-29 00:00:00
# Mean elevations -3.06
# 1 survey points in survey on 1983-04-12 00:00:00
# Mean elevations 5.91
# 38 survey points in survey on 1983-04-13 00:00:00
# Mean elevations -3.38
# 1 survey points in survey on 1983-05-25 00:00:00
# Mean elevations 5.71
# 35 survey points in survey on 1983-05-26 00:00:00
# Mean elevations -2.90
# 1 survey points in survey on 1983-06-14 00:00:00
# Mean elevations 5.93
# 33 survey points in survey on 1983-06-15 00:00:00
# Mean elevations -3.02
# 1 survey points in survey on 1983-06-30 00:00:00
# Mean elevations 5.72
# 33 survey points in survey on 1983-07-01 00:00:00
# Mean elevations -2.76
# 30 survey points in survey on 1983-07-26 00:00:00
# Mean elevations -2.29
# 1 survey points in survey on 1983-08-08 00:00:00
# Mean elevations 5.86
# 29 survey points in survey on 1983-08-09 00:00:00
# Mean elevations -3.30
# 1 survey points in survey on 1983-08-26 00:00:00
# Mean elevations 5.86
# 29 survey points in survey on 1983-08-27 00:00:00
# Mean elevations -3.03
# 35 survey points in survey on 1983-09-07 00:00:00
# Mean elevations -2.85
# 35 survey points in survey on 1983-09-19 00:00:00
# Mean elevations -3.78
# 1 survey points in survey on 1983-10-01 00:00:00
# Mean elevations 5.69
# 50 survey points in survey on 1983-10-02 00:00:00
# Mean elevations -3.04
# 1 survey points in survey on 1983-10-14 00:00:00
# Mean elevations 5.69
# 36 survey points in survey on 1983-10-15 00:00:00
# Mean elevations -2.84
# 1 survey points in survey on 1983-10-24 00:00:00
# Mean elevations 5.69
# 36 survey points in survey on 1983-10-25 00:00:00
# Mean elevations -2.84
# 1 survey points in survey on 1983-11-07 00:00:00
# Mean elevations 5.87
# 28 survey points in survey on 1983-11-08 00:00:00
# Mean elevations -2.47
# 1 survey points in survey on 1983-11-21 00:00:00
# Mean elevations 5.70
# 28 survey points in survey on 1983-11-22 00:00:00
# Mean elevations -3.03
# 1 survey points in survey on 1983-12-02 00:00:00
# Mean elevations 5.89
# 27 survey points in survey on 1983-12-03 00:00:00
# Mean elevations -3.23
# 1 survey points in survey on 1983-12-27 00:00:00
# Mean elevations 5.88
# 29 survey points in survey on 1983-12-28 00:00:00
# Mean elevations -2.45
# 2 survey points in survey on 1984-01-17 00:00:00
# Mean elevations 5.26
# 39 survey points in survey on 1984-01-18 00:00:00
# Mean elevations -3.81
# 1 survey points in survey on 1984-02-02 00:00:00
# Mean elevations 5.86
# 24 survey points in survey on 1984-02-03 00:00:00
# Mean elevations -2.50
# 1 survey points in survey on 1984-02-16 00:00:00
# Mean elevations 5.87
# 36 survey points in survey on 1984-02-17 00:00:00
# Mean elevations -2.45
# 35 survey points in survey on 1984-02-25 00:00:00
# Mean elevations -2.82
# 1 survey points in survey on 1984-03-08 00:00:00
# Mean elevations 5.89
# 34 survey points in survey on 1984-03-09 00:00:00
# Mean elevations -3.12
# 2 survey points in survey on 1984-03-20 00:00:00
# Mean elevations 5.88
# 39 survey points in survey on 1984-03-21 00:00:00
# Mean elevations -2.80
# 1 survey points in survey on 1984-04-06 00:00:00
# Mean elevations 5.90
# 29 survey points in survey on 1984-04-07 00:00:00
# Mean elevations -2.76
# 1 survey points in survey on 1984-04-13 00:00:00
# Mean elevations 5.90
# 38 survey points in survey on 1984-04-14 00:00:00
# Mean elevations -3.31
# 1 survey points in survey on 1984-04-25 00:00:00
# Mean elevations 5.87
# 27 survey points in survey on 1984-04-26 00:00:00
# Mean elevations -2.30
# 1 survey points in survey on 1984-05-09 00:00:00
# Mean elevations 5.87
# 29 survey points in survey on 1984-05-10 00:00:00
# Mean elevations -2.53
# 1 survey points in survey on 1984-05-24 00:00:00
# Mean elevations 5.90
# 34 survey points in survey on 1984-05-25 00:00:00
# Mean elevations -3.11
# 2 survey points in survey on 1984-06-01 00:00:00
# Mean elevations 5.29
# 28 survey points in survey on 1984-06-02 00:00:00
# Mean elevations -3.46
# 1 survey points in survey on 1984-06-27 00:00:00
# Mean elevations 5.85
# 32 survey points in survey on 1984-06-28 00:00:00
# Mean elevations -3.25
# 1 survey points in survey on 1984-07-27 00:00:00
# Mean elevations 5.93
# 50 survey points in survey on 1984-07-28 00:00:00
# Mean elevations -3.60
# 1 survey points in survey on 1984-08-30 00:00:00
# Mean elevations 5.87
# 21 survey points in survey on 1984-08-31 00:00:00
# Mean elevations -1.83
# 1 survey points in survey on 1984-09-06 00:00:00
# Mean elevations 5.87
# 30 survey points in survey on 1984-09-07 00:00:00
# Mean elevations -2.62
# 1 survey points in survey on 1984-09-10 00:00:00
# Mean elevations 5.86
# 28 survey points in survey on 1984-09-11 00:00:00
# Mean elevations -0.86
# 1 survey points in survey on 1984-10-02 00:00:00
# Mean elevations 5.88
# 40 survey points in survey on 1984-10-03 00:00:00
# Mean elevations -1.50
# 1 survey points in survey on 1984-10-16 00:00:00
# Mean elevations 5.85
# 40 survey points in survey on 1984-10-17 00:00:00
# Mean elevations -1.83
# 40 survey points in survey on 1984-10-30 00:00:00
# Mean elevations -2.04
# 36 survey points in survey on 1984-12-14 00:00:00
# Mean elevations -2.62
# 1 survey points in survey on 1985-01-02 00:00:00
# Mean elevations 5.74
# 40 survey points in survey on 1985-01-03 00:00:00
# Mean elevations -2.68
# 41 survey points in survey on 1985-01-06 00:00:00
# Mean elevations -2.50
# 62 survey points in survey on 1985-01-26 00:00:00
# Mean elevations -2.85
# 2 survey points in survey on 1985-03-01 00:00:00
# Mean elevations 5.46
# 33 survey points in survey on 1985-03-02 00:00:00
# Mean elevations -2.33
# 36 survey points in survey on 1985-03-16 00:00:00
# Mean elevations -2.91
# 30 survey points in survey on 1985-03-27 00:00:00
# Mean elevations -2.19
# 1 survey points in survey on 1985-05-09 00:00:00
# Mean elevations 5.94
# 43 survey points in survey on 1985-05-10 00:00:00
# Mean elevations -2.90
# 1 survey points in survey on 1985-05-31 00:00:00
# Mean elevations 4.71
# 38 survey points in survey on 1985-06-01 00:00:00
# Mean elevations -2.80
# 40 survey points in survey on 1985-06-21 00:00:00
# Mean elevations -2.90
# 1 survey points in survey on 1985-07-19 00:00:00
# Mean elevations 5.71
# 26 survey points in survey on 1985-07-20 00:00:00
# Mean elevations -0.84
# 1 survey points in survey on 1985-07-24 00:00:00
# Mean elevations 5.71
# 33 survey points in survey on 1985-07-25 00:00:00
# Mean elevations -2.03
# 45 survey points in survey on 1985-08-08 00:00:00
# Mean elevations -2.39
# 1 survey points in survey on 1985-09-06 00:00:00
# Mean elevations 5.90
# 38 survey points in survey on 1985-09-07 00:00:00
# Mean elevations -1.70
# 2 survey points in survey on 1985-09-14 00:00:00
# Mean elevations 5.26
# 35 survey points in survey on 1985-09-15 00:00:00
# Mean elevations -1.28
# 1 survey points in survey on 1985-11-06 00:00:00
# Mean elevations 5.88
# 50 survey points in survey on 1985-11-07 00:00:00
# Mean elevations -2.55
# 1 survey points in survey on 1985-11-21 00:00:00
# Mean elevations 5.88
# 40 survey points in survey on 1985-11-22 00:00:00
# Mean elevations -1.65
# 1 survey points in survey on 1985-12-09 00:00:00
# Mean elevations 5.88
# 39 survey points in survey on 1985-12-10 00:00:00
# Mean elevations -1.74
# 10 survey points in survey on 1985-12-31 00:00:00
# Mean elevations 4.56
# 36 survey points in survey on 1986-01-01 00:00:00
# Mean elevations -3.65
# 10 survey points in survey on 1986-01-29 00:00:00
# Mean elevations 4.56
# 29 survey points in survey on 1986-01-30 00:00:00
# Mean elevations -3.72
# 10 survey points in survey on 1986-02-10 00:00:00
# Mean elevations 4.56
# 28 survey points in survey on 1986-02-11 00:00:00
# Mean elevations -3.88
# 10 survey points in survey on 1986-03-11 00:00:00
# Mean elevations 4.56
# 33 survey points in survey on 1986-03-12 00:00:00
# Mean elevations -3.48
# 10 survey points in survey on 1986-03-30 00:00:00
# Mean elevations 4.56
# 29 survey points in survey on 1986-03-31 00:00:00
# Mean elevations -3.32
# 10 survey points in survey on 1986-04-16 00:00:00
# Mean elevations 4.56
# 40 survey points in survey on 1986-04-17 00:00:00
# Mean elevations -4.29
# 10 survey points in survey on 1986-04-22 00:00:00
# Mean elevations 4.56
# 36 survey points in survey on 1986-04-23 00:00:00
# Mean elevations -3.18
# 10 survey points in survey on 1986-05-15 00:00:00
# Mean elevations 4.56
# 54 survey points in survey on 1986-05-16 00:00:00
# Mean elevations -3.67
# 10 survey points in survey on 1986-06-02 00:00:00
# Mean elevations 4.56
# 37 survey points in survey on 1986-06-03 00:00:00
# Mean elevations -4.32
# 43 survey points in survey on 1986-06-24 00:00:00
# Mean elevations -1.86
# 31 survey points in survey on 1986-07-10 00:00:00
# Mean elevations -1.24
# 9 survey points in survey on 1986-08-13 00:00:00
# Mean elevations 4.66
# 20 survey points in survey on 1986-08-14 00:00:00
# Mean elevations -3.28
# 7 survey points in survey on 1986-08-18 00:00:00
# Mean elevations 5.16
# 21 survey points in survey on 1986-08-19 00:00:00
# Mean elevations -2.70
# 8 survey points in survey on 1986-09-03 00:00:00
# Mean elevations 4.54
# 34 survey points in survey on 1986-09-04 00:00:00
# Mean elevations -2.45
# 5 survey points in survey on 1986-11-25 00:00:00
# Mean elevations 4.42
# 20 survey points in survey on 1986-11-26 00:00:00
# Mean elevations -3.75
# 4 survey points in survey on 1986-12-18 00:00:00
# Mean elevations 4.80
# 22 survey points in survey on 1986-12-19 00:00:00
# Mean elevations -4.41
# 38 survey points in survey on 1987-01-07 00:00:00
# Mean elevations -0.29
# 37 survey points in survey on 1987-01-22 00:00:00
# Mean elevations -0.20
# 41 survey points in survey on 1987-01-24 00:00:00
# Mean elevations -0.50
# 36 survey points in survey on 1987-02-14 00:00:00
# Mean elevations -0.47
# 13 survey points in survey on 1987-02-19 00:00:00
# Mean elevations 5.31
# 23 survey points in survey on 1987-02-20 00:00:00
# Mean elevations -3.58
# 40 survey points in survey on 1987-03-19 00:00:00
# Mean elevations -2.27
# 27 survey points in survey on 1987-03-27 00:00:00
# Mean elevations -1.53
# 27 survey points in survey on 1987-05-01 00:00:00
# Mean elevations -0.41
# 30 survey points in survey on 1987-05-12 00:00:00
# Mean elevations -1.04
# 10 survey points in survey on 1987-05-29 00:00:00
# Mean elevations 4.93
# 36 survey points in survey on 1987-05-30 00:00:00
# Mean elevations -2.58
# 10 survey points in survey on 1987-07-06 00:00:00
# Mean elevations 4.93
# 22 survey points in survey on 1987-07-07 00:00:00
# Mean elevations -3.70
# 30 survey points in survey on 1987-08-01 00:00:00
# Mean elevations -1.67
# 40 survey points in survey on 1987-08-13 00:00:00
# Mean elevations -1.46
# 8 survey points in survey on 1987-09-08 00:00:00
# Mean elevations 4.43
# 27 survey points in survey on 1987-09-09 00:00:00
# Mean elevations -3.49
# 7 survey points in survey on 1987-11-05 00:00:00
# Mean elevations 4.59
# 25 survey points in survey on 1987-11-06 00:00:00
# Mean elevations -3.71
# 7 survey points in survey on 1987-11-13 00:00:00
# Mean elevations 4.59
# 27 survey points in survey on 1987-11-14 00:00:00
# Mean elevations -3.50
# 7 survey points in survey on 1987-11-25 00:00:00
# Mean elevations 4.59
# 36 survey points in survey on 1987-11-26 00:00:00
# Mean elevations -3.80
# 7 survey points in survey on 1987-12-02 00:00:00
# Mean elevations 4.59
# 28 survey points in survey on 1987-12-03 00:00:00
# Mean elevations -3.78
# 41 survey points in survey on 1987-12-24 00:00:00
# Mean elevations -2.05
# 35 survey points in survey on 1988-01-05 00:00:00
# Mean elevations -1.40
# 42 survey points in survey on 1988-01-13 00:00:00
# Mean elevations -1.74
# 11 survey points in survey on 1988-02-18 00:00:00
# Mean elevations 4.59
# 22 survey points in survey on 1988-02-19 00:00:00
# Mean elevations -4.22
# 10 survey points in survey on 1988-03-03 00:00:00
# Mean elevations 4.72
# 26 survey points in survey on 1988-03-04 00:00:00
# Mean elevations -4.22
# 10 survey points in survey on 1988-03-21 00:00:00
# Mean elevations 4.72
# 21 survey points in survey on 1988-03-22 00:00:00
# Mean elevations -3.11
# 5 survey points in survey on 1988-04-02 00:00:00
# Mean elevations -7.37
# 8 survey points in survey on 1988-04-15 00:00:00
# Mean elevations 4.98
# 27 survey points in survey on 1988-04-16 00:00:00
# Mean elevations -2.44
# 10 survey points in survey on 1988-04-21 00:00:00
# Mean elevations 4.72
# 20 survey points in survey on 1988-04-22 00:00:00
# Mean elevations -3.20
# 10 survey points in survey on 1988-05-18 00:00:00
# Mean elevations 4.72
# 25 survey points in survey on 1988-05-19 00:00:00
# Mean elevations -3.86
# 10 survey points in survey on 1988-06-02 00:00:00
# Mean elevations 4.72
# 19 survey points in survey on 1988-06-03 00:00:00
# Mean elevations -3.35
# 37 survey points in survey on 1988-06-22 00:00:00
# Mean elevations -0.32
# 15 survey points in survey on 1988-07-20 00:00:00
# Mean elevations 4.94
# 19 survey points in survey on 1988-07-21 00:00:00
# Mean elevations -3.82
# 15 survey points in survey on 1988-08-08 00:00:00
# Mean elevations 4.94
# 18 survey points in survey on 1988-08-09 00:00:00
# Mean elevations -3.50
# 15 survey points in survey on 1988-10-11 00:00:00
# Mean elevations 4.94
# 18 survey points in survey on 1988-10-12 00:00:00
# Mean elevations -3.48
# 15 survey points in survey on 1988-11-09 00:00:00
# Mean elevations 4.94
# 21 survey points in survey on 1988-11-10 00:00:00
# Mean elevations -3.23
# 27 survey points in survey on 1989-01-18 00:00:00
# Mean elevations -1.36
# 25 survey points in survey on 1989-02-03 00:00:00
# Mean elevations -0.98
# 24 survey points in survey on 1989-02-17 00:00:00
# Mean elevations -1.02
# 9 survey points in survey on 1989-02-21 00:00:00
# Mean elevations 4.97
# 19 survey points in survey on 1989-02-22 00:00:00
# Mean elevations -4.34
# 24 survey points in survey on 1989-02-28 00:00:00
# Mean elevations -0.91
# 20 survey points in survey on 1989-03-13 00:00:00
# Mean elevations -1.70
# 26 survey points in survey on 1989-03-29 00:00:00
# Mean elevations -1.00
# 4 survey points in survey on 1989-04-26 00:00:00
# Mean elevations 5.27
# 21 survey points in survey on 1989-04-27 00:00:00
# Mean elevations -2.40
# 8 survey points in survey on 1989-05-08 00:00:00
# Mean elevations 5.10
# 18 survey points in survey on 1989-05-09 00:00:00
# Mean elevations -4.07
# 9 survey points in survey on 1989-05-16 00:00:00
# Mean elevations 4.77
# 17 survey points in survey on 1989-05-17 00:00:00
# Mean elevations -3.87
# 1 survey points in survey on 1989-05-24 00:00:00
# Mean elevations 5.65
# 25 survey points in survey on 1989-05-25 00:00:00
# Mean elevations -1.04
# 7 survey points in survey on 1989-06-29 00:00:00
# Mean elevations 5.48
# 20 survey points in survey on 1989-06-30 00:00:00
# Mean elevations -2.83
# 7 survey points in survey on 1989-07-19 00:00:00
# Mean elevations 5.48
# 17 survey points in survey on 1989-07-20 00:00:00
# Mean elevations -3.01
# 9 survey points in survey on 1989-07-26 00:00:00
# Mean elevations 4.77
# 16 survey points in survey on 1989-07-27 00:00:00
# Mean elevations -3.77
# 29 survey points in survey on 1989-08-16 00:00:00
# Mean elevations -1.27
# 20 survey points in survey on 1989-08-25 00:00:00
# Mean elevations -0.77
# 21 survey points in survey on 1989-09-13 00:00:00
# Mean elevations -2.18
# 5 survey points in survey on 1989-10-03 00:00:00
# Mean elevations 4.91
# 20 survey points in survey on 1989-10-04 00:00:00
# Mean elevations -3.36
# 5 survey points in survey on 1989-10-10 00:00:00
# Mean elevations 4.91
# 16 survey points in survey on 1989-10-11 00:00:00
# Mean elevations -3.47
# 4 survey points in survey on 1989-11-01 00:00:00
# Mean elevations 4.70
# 16 survey points in survey on 1989-11-02 00:00:00
# Mean elevations -2.82
# 5 survey points in survey on 1989-11-17 00:00:00
# Mean elevations 4.91
# 15 survey points in survey on 1989-11-18 00:00:00
# Mean elevations -3.21
# 5 survey points in survey on 1989-11-28 00:00:00
# Mean elevations 4.91
# 15 survey points in survey on 1989-11-29 00:00:00
# Mean elevations -2.95
# 5 survey points in survey on 1989-12-07 00:00:00
# Mean elevations 4.92
# 16 survey points in survey on 1989-12-08 00:00:00
# Mean elevations -2.54
# 20 survey points in survey on 1989-12-13 00:00:00
# Mean elevations -0.77
# 25 survey points in survey on 1989-12-22 00:00:00
# Mean elevations -1.58
# 30 survey points in survey on 1989-12-29 00:00:00
# Mean elevations -2.47
# 21 survey points in survey on 1990-01-30 00:00:00
# Mean elevations -0.85
# 19 survey points in survey on 1990-02-10 00:00:00
# Mean elevations -0.38
# 20 survey points in survey on 1990-02-17 00:00:00
# Mean elevations -0.37
# 19 survey points in survey on 1990-03-10 00:00:00
# Mean elevations 0.14
# 6 survey points in survey on 1990-03-19 00:00:00
# Mean elevations 5.38
# 13 survey points in survey on 1990-03-20 00:00:00
# Mean elevations -2.97
# 6 survey points in survey on 1990-04-09 00:00:00
# Mean elevations 5.38
# 15 survey points in survey on 1990-04-10 00:00:00
# Mean elevations -2.97
# 440 survey points in survey on 1990-05-02 00:00:00
# Mean elevations -11.99
# 4 survey points in survey on 1990-05-08 00:00:00
# Mean elevations 5.53
# 189 survey points in survey on 1990-05-09 00:00:00
# Mean elevations -4.59
# 7 survey points in survey on 1990-05-24 00:00:00
# Mean elevations 5.06
# 151 survey points in survey on 1990-05-25 00:00:00
# Mean elevations -4.19
# 7 survey points in survey on 1990-06-15 00:00:00
# Mean elevations 5.06
# 140 survey points in survey on 1990-06-16 00:00:00
# Mean elevations -4.16
# 181 survey points in survey on 1990-07-12 00:00:00
# Mean elevations -3.76
# 11 survey points in survey on 1990-08-20 00:00:00
# Mean elevations 4.88
# 206 survey points in survey on 1990-08-21 00:00:00
# Mean elevations -3.66
# 528 survey points in survey on 1990-09-07 00:00:00
# Mean elevations -3.83
# 62 survey points in survey on 1990-09-20 00:00:00
# Mean elevations -2.64
# 226 survey points in survey on 1990-10-02 00:00:00
# Mean elevations -2.79
# 151 survey points in survey on 1990-10-03 00:00:00
# Mean elevations -2.65
# 169 survey points in survey on 1990-10-04 00:00:00
# Mean elevations -2.60
# 178 survey points in survey on 1990-10-05 00:00:00
# Mean elevations -2.63
# 229 survey points in survey on 1990-10-06 00:00:00
# Mean elevations -2.68
# 214 survey points in survey on 1990-10-07 00:00:00
# Mean elevations -2.54
# 193 survey points in survey on 1990-10-08 00:00:00
# Mean elevations -3.04
# 207 survey points in survey on 1990-10-09 00:00:00
# Mean elevations -2.70
# 242 survey points in survey on 1990-10-10 00:00:00
# Mean elevations -2.01
# 170 survey points in survey on 1990-10-11 00:00:00
# Mean elevations -2.00
# 123 survey points in survey on 1990-10-12 00:00:00
# Mean elevations -1.55
# 87 survey points in survey on 1990-10-13 00:00:00
# Mean elevations -1.33
# 63 survey points in survey on 1990-10-14 00:00:00
# Mean elevations -0.78
# 171 survey points in survey on 1990-10-15 00:00:00
# Mean elevations -2.64
# 212 survey points in survey on 1990-10-16 00:00:00
# Mean elevations -4.63
# 215 survey points in survey on 1990-10-17 00:00:00
# Mean elevations -2.82
# 195 survey points in survey on 1990-10-18 00:00:00
# Mean elevations -2.72
# 187 survey points in survey on 1990-10-19 00:00:00
# Mean elevations -2.70
# 203 survey points in survey on 1990-10-20 00:00:00
# Mean elevations -2.65
# 9 survey points in survey on 1990-10-31 00:00:00
# Mean elevations 4.74
# 350 survey points in survey on 1990-11-01 00:00:00
# Mean elevations -4.42
# 11 survey points in survey on 1990-11-15 00:00:00
# Mean elevations 4.88
# 298 survey points in survey on 1990-11-16 00:00:00
# Mean elevations -4.48
# 11 survey points in survey on 1991-01-11 00:00:00
# Mean elevations 4.88
# 347 survey points in survey on 1991-01-12 00:00:00
# Mean elevations -4.04
# 10 survey points in survey on 1991-01-18 00:00:00
# Mean elevations 4.82
# 206 survey points in survey on 1991-01-19 00:00:00
# Mean elevations -4.23
# 11 survey points in survey on 1991-02-06 00:00:00
# Mean elevations 4.88
# 197 survey points in survey on 1991-02-07 00:00:00
# Mean elevations -3.89
# 11 survey points in survey on 1991-02-20 00:00:00
# Mean elevations 4.88
# 169 survey points in survey on 1991-02-21 00:00:00
# Mean elevations -3.92
# 11 survey points in survey on 1991-03-12 00:00:00
# Mean elevations 4.88
# 204 survey points in survey on 1991-03-13 00:00:00
# Mean elevations -3.48
# 10 survey points in survey on 1991-03-27 00:00:00
# Mean elevations 4.82
# 359 survey points in survey on 1991-03-28 00:00:00
# Mean elevations -4.22
# 170 survey points in survey on 1991-04-23 00:00:00
# Mean elevations -3.87
# 364 survey points in survey on 1991-05-11 00:00:00
# Mean elevations -3.67
# 381 survey points in survey on 1991-05-25 00:00:00
# Mean elevations -4.41
# 6 survey points in survey on 1991-06-10 00:00:00
# Mean elevations 4.82
# 381 survey points in survey on 1991-06-11 00:00:00
# Mean elevations -4.37
# 378 survey points in survey on 1991-06-28 00:00:00
# Mean elevations -4.53
# 5 survey points in survey on 1991-07-12 00:00:00
# Mean elevations 4.70
# 173 survey points in survey on 1991-07-13 00:00:00
# Mean elevations -3.91
# 3 survey points in survey on 1991-07-26 00:00:00
# Mean elevations 3.94
# 184 survey points in survey on 1991-07-27 00:00:00
# Mean elevations -3.97
# 6 survey points in survey on 1991-08-13 00:00:00
# Mean elevations 4.82
# 175 survey points in survey on 1991-08-14 00:00:00
# Mean elevations -3.69
# 6 survey points in survey on 1991-08-19 00:00:00
# Mean elevations 4.82
# 379 survey points in survey on 1991-08-20 00:00:00
# Mean elevations -4.03
# 385 survey points in survey on 1991-08-24 00:00:00
# Mean elevations -4.64
# 215 survey points in survey on 1991-09-06 00:00:00
# Mean elevations -3.71
# 3 survey points in survey on 1991-09-23 00:00:00
# Mean elevations 3.94
# 376 survey points in survey on 1991-09-24 00:00:00
# Mean elevations -4.46
# 6 survey points in survey on 1991-10-09 00:00:00
# Mean elevations 4.82
# 358 survey points in survey on 1991-10-10 00:00:00
# Mean elevations -4.36
# 3 survey points in survey on 1991-10-23 00:00:00
# Mean elevations 3.94
# 195 survey points in survey on 1991-10-24 00:00:00
# Mean elevations -3.99
# 2 survey points in survey on 1991-11-03 00:00:00
# Mean elevations 4.59
# 352 survey points in survey on 1991-11-04 00:00:00
# Mean elevations -4.43
# 372 survey points in survey on 1991-11-13 00:00:00
# Mean elevations -4.33
# 213 survey points in survey on 1991-12-04 00:00:00
# Mean elevations -3.90
# 2 survey points in survey on 1991-12-18 00:00:00
# Mean elevations 5.15
# 188 survey points in survey on 1991-12-19 00:00:00
# Mean elevations -3.91
# 367 survey points in survey on 1992-01-03 00:00:00
# Mean elevations -4.42
# 4 survey points in survey on 1992-01-06 00:00:00
# Mean elevations 5.39
# 332 survey points in survey on 1992-01-07 00:00:00
# Mean elevations -4.10
# 3 survey points in survey on 1992-01-24 00:00:00
# Mean elevations 5.35
# 347 survey points in survey on 1992-01-25 00:00:00
# Mean elevations -4.40
# 2 survey points in survey on 1992-02-11 00:00:00
# Mean elevations 5.15
# 350 survey points in survey on 1992-02-12 00:00:00
# Mean elevations -4.29
# 4 survey points in survey on 1992-02-27 00:00:00
# Mean elevations 5.39
# 195 survey points in survey on 1992-02-28 00:00:00
# Mean elevations -3.59
# 4 survey points in survey on 1992-03-10 00:00:00
# Mean elevations 5.39
# 355 survey points in survey on 1992-03-11 00:00:00
# Mean elevations -4.25
# 3 survey points in survey on 1992-03-25 00:00:00
# Mean elevations 5.35
# 384 survey points in survey on 1992-03-26 00:00:00
# Mean elevations -4.48
# 4 survey points in survey on 1992-03-30 00:00:00
# Mean elevations 5.39
# 363 survey points in survey on 1992-03-31 00:00:00
# Mean elevations -4.48
# 3 survey points in survey on 1992-05-04 00:00:00
# Mean elevations 5.71
# 26 survey points in survey on 1992-05-05 00:00:00
# Mean elevations -3.17
# 3 survey points in survey on 1992-05-11 00:00:00
# Mean elevations 5.71
# 29 survey points in survey on 1992-05-12 00:00:00
# Mean elevations -3.26
# 50 survey points in survey on 1992-05-29 00:00:00
# Mean elevations 1.70
# 385 survey points in survey on 1992-06-26 00:00:00
# Mean elevations -3.51
# 263 survey points in survey on 1992-07-16 00:00:00
# Mean elevations -3.04
# 228 survey points in survey on 1992-07-29 00:00:00
# Mean elevations -2.86
# 30 survey points in survey on 1992-08-10 00:00:00
# Mean elevations 4.99
# 277 survey points in survey on 1992-08-11 00:00:00
# Mean elevations -4.36
# 31 survey points in survey on 1992-08-20 00:00:00
# Mean elevations 5.00
# 316 survey points in survey on 1992-08-21 00:00:00
# Mean elevations -4.47
# 30 survey points in survey on 1992-09-02 00:00:00
# Mean elevations 4.99
# 172 survey points in survey on 1992-09-03 00:00:00
# Mean elevations -3.77
# 212 survey points in survey on 1992-09-17 00:00:00
# Mean elevations -2.30
# 34 survey points in survey on 1992-09-21 00:00:00
# Mean elevations 4.83
# 325 survey points in survey on 1992-09-22 00:00:00
# Mean elevations -4.39
# 29 survey points in survey on 1992-09-28 00:00:00
# Mean elevations 5.12
# 347 survey points in survey on 1992-09-29 00:00:00
# Mean elevations -3.92
# 389 survey points in survey on 1992-10-27 00:00:00
# Mean elevations -3.61
# 387 survey points in survey on 1992-12-19 00:00:00
# Mean elevations -3.66
# 266 survey points in survey on 1993-01-05 00:00:00
# Mean elevations -2.88
# 390 survey points in survey on 1993-01-14 00:00:00
# Mean elevations -3.63
# 28 survey points in survey on 1993-01-19 00:00:00
# Mean elevations 5.25
# 263 survey points in survey on 1993-01-20 00:00:00
# Mean elevations -3.46
# 210 survey points in survey on 1993-02-12 00:00:00
# Mean elevations -2.39
# 28 survey points in survey on 1993-03-12 00:00:00
# Mean elevations 5.25
# 243 survey points in survey on 1993-03-13 00:00:00
# Mean elevations -3.31
# 26 survey points in survey on 1993-03-15 00:00:00
# Mean elevations 5.22
# 269 survey points in survey on 1993-03-16 00:00:00
# Mean elevations -3.56
# 28 survey points in survey on 1993-04-12 00:00:00
# Mean elevations 5.25
# 276 survey points in survey on 1993-04-13 00:00:00
# Mean elevations -3.61
# 28 survey points in survey on 1993-04-26 00:00:00
# Mean elevations 5.25
# 225 survey points in survey on 1993-04-27 00:00:00
# Mean elevations -3.79
# 25 survey points in survey on 1993-05-11 00:00:00
# Mean elevations 5.21
# 223 survey points in survey on 1993-05-12 00:00:00
# Mean elevations -3.62
# 273 survey points in survey on 1993-05-22 00:00:00
# Mean elevations -2.83
# 28 survey points in survey on 1993-05-28 00:00:00
# Mean elevations 5.25
# 249 survey points in survey on 1993-05-29 00:00:00
# Mean elevations -3.76
# 27 survey points in survey on 1993-06-10 00:00:00
# Mean elevations 5.24
# 278 survey points in survey on 1993-06-11 00:00:00
# Mean elevations -4.06
# 30 survey points in survey on 1993-06-30 00:00:00
# Mean elevations 5.13
# 205 survey points in survey on 1993-07-01 00:00:00
# Mean elevations -4.23
# 27 survey points in survey on 1993-07-08 00:00:00
# Mean elevations 5.24
# 322 survey points in survey on 1993-07-09 00:00:00
# Mean elevations -4.32
# 27 survey points in survey on 1993-08-05 00:00:00
# Mean elevations 5.24
# 244 survey points in survey on 1993-08-06 00:00:00
# Mean elevations -3.87
# 28 survey points in survey on 1993-08-29 00:00:00
# Mean elevations 5.25
# 273 survey points in survey on 1993-08-30 00:00:00
# Mean elevations -4.48
# 27 survey points in survey on 1993-09-02 00:00:00
# Mean elevations 5.24
# 180 survey points in survey on 1993-09-03 00:00:00
# Mean elevations -3.11
# 31 survey points in survey on 1993-09-16 00:00:00
# Mean elevations 5.08
# 364 survey points in survey on 1993-09-17 00:00:00
# Mean elevations -4.00
# 32 survey points in survey on 1993-10-05 00:00:00
# Mean elevations 5.02
# 188 survey points in survey on 1993-10-06 00:00:00
# Mean elevations -3.05
# 219 survey points in survey on 1993-10-16 00:00:00
# Mean elevations -2.46
# 342 survey points in survey on 1993-11-23 00:00:00
# Mean elevations -4.03
# 320 survey points in survey on 1993-11-30 00:00:00
# Mean elevations -3.26
# 267 survey points in survey on 1993-12-09 00:00:00
# Mean elevations -3.40
# 10 survey points in survey on 1994-01-06 00:00:00
# Mean elevations 5.33
# 38 survey points in survey on 1994-01-07 00:00:00
# Mean elevations -3.80
# 359 survey points in survey on 1994-01-25 00:00:00
# Mean elevations -3.50
# 240 survey points in survey on 1994-03-01 00:00:00
# Mean elevations -5.00
# 64 survey points in survey on 1994-03-05 00:00:00
# Mean elevations -1.32
# 51 survey points in survey on 1994-03-24 00:00:00
# Mean elevations -1.12
# 39 survey points in survey on 1994-04-07 00:00:00
# Mean elevations -0.09
# 11 survey points in survey on 1994-04-12 00:00:00
# Mean elevations 5.38
# 36 survey points in survey on 1994-04-13 00:00:00
# Mean elevations -2.63
# 11 survey points in survey on 1994-04-28 00:00:00
# Mean elevations 5.38
# 37 survey points in survey on 1994-04-29 00:00:00
# Mean elevations -3.11
# 11 survey points in survey on 1994-05-06 00:00:00
# Mean elevations 5.38
# 30 survey points in survey on 1994-05-07 00:00:00
# Mean elevations -2.90
# 12 survey points in survey on 1994-05-24 00:00:00
# Mean elevations 5.24
# 29 survey points in survey on 1994-05-25 00:00:00
# Mean elevations -3.28
# 11 survey points in survey on 1994-06-09 00:00:00
# Mean elevations 5.38
# 309 survey points in survey on 1994-06-10 00:00:00
# Mean elevations -4.15
# 368 survey points in survey on 1994-07-02 00:00:00
# Mean elevations -2.68
# 278 survey points in survey on 1994-07-09 00:00:00
# Mean elevations -3.19
# 9 survey points in survey on 1994-07-30 00:00:00
# Mean elevations 5.51
# 371 survey points in survey on 1994-07-31 00:00:00
# Mean elevations -3.86
# 379 survey points in survey on 1994-08-09 00:00:00
# Mean elevations -2.43
# 380 survey points in survey on 1994-08-11 00:00:00
# Mean elevations -1.46
# 379 survey points in survey on 1994-08-13 00:00:00
# Mean elevations -1.50
# 255 survey points in survey on 1994-08-14 00:00:00
# Mean elevations -21.46
# 379 survey points in survey on 1994-08-17 00:00:00
# Mean elevations -1.57
# 378 survey points in survey on 1994-08-19 00:00:00
# Mean elevations -1.68
# 379 survey points in survey on 1994-08-21 00:00:00
# Mean elevations -1.85
# 378 survey points in survey on 1994-09-08 00:00:00
# Mean elevations -1.52
# 10 survey points in survey on 1994-09-21 00:00:00
# Mean elevations 5.25
# 701 survey points in survey on 1994-09-22 00:00:00
# Mean elevations -3.89
# 10 survey points in survey on 1994-10-04 00:00:00
# Mean elevations 5.25
# 629 survey points in survey on 1994-10-05 00:00:00
# Mean elevations -2.91
# 495 survey points in survey on 1994-10-06 00:00:00
# Mean elevations -2.43
# 10 survey points in survey on 1994-10-07 00:00:00
# Mean elevations 5.25
# 483 survey points in survey on 1994-10-08 00:00:00
# Mean elevations -2.31
# 441 survey points in survey on 1994-10-09 00:00:00
# Mean elevations -2.35
# 480 survey points in survey on 1994-10-10 00:00:00
# Mean elevations -2.48
# 490 survey points in survey on 1994-10-11 00:00:00
# Mean elevations -2.43
# 540 survey points in survey on 1994-10-12 00:00:00
# Mean elevations -2.48
# 531 survey points in survey on 1994-10-13 00:00:00
# Mean elevations -2.56
# 10 survey points in survey on 1994-10-14 00:00:00
# Mean elevations 5.25
# 444 survey points in survey on 1994-10-15 00:00:00
# Mean elevations -2.20
# 10 survey points in survey on 1994-10-19 00:00:00
# Mean elevations 5.25
# 221 survey points in survey on 1994-10-20 00:00:00
# Mean elevations -0.28
# 543 survey points in survey on 1994-10-21 00:00:00
# Mean elevations -2.36
# 458 survey points in survey on 1994-10-22 00:00:00
# Mean elevations -2.29
# 9 survey points in survey on 1994-11-21 00:00:00
# Mean elevations 5.51
# 725 survey points in survey on 1994-11-22 00:00:00
# Mean elevations -3.81
# 10 survey points in survey on 1994-12-06 00:00:00
# Mean elevations 5.53
# 762 survey points in survey on 1994-12-07 00:00:00
# Mean elevations -3.84
# 9 survey points in survey on 1995-01-25 00:00:00
# Mean elevations 5.51
# 829 survey points in survey on 1995-01-26 00:00:00
# Mean elevations -4.37
# 10 survey points in survey on 1995-02-23 00:00:00
# Mean elevations 5.53
# 979 survey points in survey on 1995-02-24 00:00:00
# Mean elevations -4.55
# 10 survey points in survey on 1995-03-21 00:00:00
# Mean elevations 5.53
# 994 survey points in survey on 1995-03-22 00:00:00
# Mean elevations -4.64
# 10 survey points in survey on 1995-04-03 00:00:00
# Mean elevations 5.53
# 941 survey points in survey on 1995-04-04 00:00:00
# Mean elevations -4.12
# 932 survey points in survey on 1995-04-21 00:00:00
# Mean elevations -4.32
# 922 survey points in survey on 1995-04-22 00:00:00
# Mean elevations -4.42
# 11 survey points in survey on 1995-05-22 00:00:00
# Mean elevations 5.38
# 1062 survey points in survey on 1995-05-23 00:00:00
# Mean elevations -4.54
# 10 survey points in survey on 1995-06-14 00:00:00
# Mean elevations 5.35
# 969 survey points in survey on 1995-06-15 00:00:00
# Mean elevations -3.74
# 11 survey points in survey on 1995-07-03 00:00:00
# Mean elevations 5.38
# 1147 survey points in survey on 1995-07-04 00:00:00
# Mean elevations -4.57
# 11 survey points in survey on 1995-07-14 00:00:00
# Mean elevations 5.38
# 825 survey points in survey on 1995-07-15 00:00:00
# Mean elevations -3.70
# 11 survey points in survey on 1995-08-02 00:00:00
# Mean elevations 5.39
# 934 survey points in survey on 1995-08-03 00:00:00
# Mean elevations -4.15
# 69 survey points in survey on 1995-08-15 00:00:00
# Mean elevations 3.52
# 11 survey points in survey on 1995-09-08 00:00:00
# Mean elevations 5.38
# 1060 survey points in survey on 1995-09-09 00:00:00
# Mean elevations -4.39
# 1021 survey points in survey on 1995-10-04 00:00:00
# Mean elevations -4.13
# 13 survey points in survey on 1995-11-03 00:00:00
# Mean elevations 5.10
# 862 survey points in survey on 1995-11-04 00:00:00
# Mean elevations -4.46
# 11 survey points in survey on 1995-11-10 00:00:00
# Mean elevations 5.38
# 822 survey points in survey on 1995-11-11 00:00:00
# Mean elevations -4.04
# 882 survey points in survey on 1995-12-07 00:00:00
# Mean elevations -4.36
# 11 survey points in survey on 1995-12-12 00:00:00
# Mean elevations 5.39
# 1011 survey points in survey on 1995-12-13 00:00:00
# Mean elevations -4.74
# 10 survey points in survey on 1996-01-10 00:00:00
# Mean elevations 5.13
# 757 survey points in survey on 1996-01-11 00:00:00
# Mean elevations -4.34
# 12 survey points in survey on 1996-01-25 00:00:00
# Mean elevations 5.24
# 824 survey points in survey on 1996-01-26 00:00:00
# Mean elevations -4.60
# 12 survey points in survey on 1996-02-25 00:00:00
# Mean elevations 5.24
# 961 survey points in survey on 1996-02-26 00:00:00
# Mean elevations -4.58
# 11 survey points in survey on 1996-03-05 00:00:00
# Mean elevations 5.39
# 990 survey points in survey on 1996-03-06 00:00:00
# Mean elevations -4.55
# 1 survey points in survey on 1996-03-14 00:00:00
# Mean elevations 4.99
# 1140 survey points in survey on 1996-03-15 00:00:00
# Mean elevations -4.80
# 11 survey points in survey on 1996-04-04 00:00:00
# Mean elevations 5.38
# 1128 survey points in survey on 1996-04-05 00:00:00
# Mean elevations -4.69
# 11 survey points in survey on 1996-04-16 00:00:00
# Mean elevations 5.39
# 1069 survey points in survey on 1996-04-17 00:00:00
# Mean elevations -5.07
# 12 survey points in survey on 1996-05-03 00:00:00
# Mean elevations 5.24
# 1096 survey points in survey on 1996-05-04 00:00:00
# Mean elevations -5.38
# 9 survey points in survey on 1996-05-31 00:00:00
# Mean elevations 5.30
# 1048 survey points in survey on 1996-06-01 00:00:00
# Mean elevations -4.81
# 12 survey points in survey on 1996-07-06 00:00:00
# Mean elevations 5.24
# 1158 survey points in survey on 1996-07-07 00:00:00
# Mean elevations -3.85
# 12 survey points in survey on 1996-07-14 00:00:00
# Mean elevations 5.23
# 1183 survey points in survey on 1996-07-15 00:00:00
# Mean elevations -4.71
# 11 survey points in survey on 1996-07-24 00:00:00
# Mean elevations 5.19
# 1084 survey points in survey on 1996-07-25 00:00:00
# Mean elevations -4.95
# 12 survey points in survey on 1996-08-19 00:00:00
# Mean elevations 5.24
# 1177 survey points in survey on 1996-08-20 00:00:00
# Mean elevations -4.54
# 11 survey points in survey on 1996-09-23 00:00:00
# Mean elevations 5.38
# 1175 survey points in survey on 1996-09-24 00:00:00
# Mean elevations -4.96
# 1161 survey points in survey on 1996-10-10 00:00:00
# Mean elevations -4.40
# 1196 survey points in survey on 1996-11-01 00:00:00
# Mean elevations -4.71
# 931 survey points in survey on 1996-11-06 00:00:00
# Mean elevations -3.65
# 18 survey points in survey on 1996-11-21 00:00:00
# Mean elevations 5.42
# 1178 survey points in survey on 1996-11-22 00:00:00
# Mean elevations -4.61
# 52 survey points in survey on 1996-12-19 00:00:00
# Mean elevations 5.41
# 921 survey points in survey on 1996-12-20 00:00:00
# Mean elevations -4.56
# 51 survey points in survey on 1997-01-08 00:00:00
# Mean elevations 5.40
# 1025 survey points in survey on 1997-01-09 00:00:00
# Mean elevations -4.42
# 49 survey points in survey on 1997-01-22 00:00:00
# Mean elevations 5.51
# 797 survey points in survey on 1997-01-23 00:00:00
# Mean elevations -4.12
# 51 survey points in survey on 1997-02-12 00:00:00
# Mean elevations 5.44
# 815 survey points in survey on 1997-02-13 00:00:00
# Mean elevations -4.08
# 47 survey points in survey on 1997-03-07 00:00:00
# Mean elevations 5.54
# 770 survey points in survey on 1997-03-08 00:00:00
# Mean elevations -4.23
# 47 survey points in survey on 1997-03-18 00:00:00
# Mean elevations 5.58
# 779 survey points in survey on 1997-03-19 00:00:00
# Mean elevations -4.23
# 52 survey points in survey on 1997-04-03 00:00:00
# Mean elevations 5.41
# 740 survey points in survey on 1997-04-04 00:00:00
# Mean elevations -4.44
# 52 survey points in survey on 1997-04-30 00:00:00
# Mean elevations 5.41
# 802 survey points in survey on 1997-05-01 00:00:00
# Mean elevations -4.35
# 51 survey points in survey on 1997-05-14 00:00:00
# Mean elevations 5.40
# 1778 survey points in survey on 1997-05-15 00:00:00
# Mean elevations -4.47
# 52 survey points in survey on 1997-06-10 00:00:00
# Mean elevations 5.41
# 860 survey points in survey on 1997-06-11 00:00:00
# Mean elevations -4.39
# 51 survey points in survey on 1997-06-17 00:00:00
# Mean elevations 5.40
# 856 survey points in survey on 1997-06-18 00:00:00
# Mean elevations -4.38
# 693 survey points in survey on 1997-06-24 00:00:00
# Mean elevations -2.71
# 37 survey points in survey on 1997-06-25 00:00:00
# Mean elevations 2.02
# 814 survey points in survey on 1997-07-30 00:00:00
# Mean elevations -2.67
# 64 survey points in survey on 1997-08-07 00:00:00
# Mean elevations 5.35
# 524 survey points in survey on 1997-08-08 00:00:00
# Mean elevations -3.36
# 64 survey points in survey on 1997-08-21 00:00:00
# Mean elevations 5.35
# 726 survey points in survey on 1997-08-22 00:00:00
# Mean elevations -3.39
# 64 survey points in survey on 1997-08-28 00:00:00
# Mean elevations 5.35
# 733 survey points in survey on 1997-08-29 00:00:00
# Mean elevations -3.54
# 63 survey points in survey on 1997-09-06 00:00:00
# Mean elevations 5.38
# 502 survey points in survey on 1997-09-07 00:00:00
# Mean elevations -3.13
# 64 survey points in survey on 1997-09-13 00:00:00
# Mean elevations 5.35
# 674 survey points in survey on 1997-09-14 00:00:00
# Mean elevations -3.39
# 1196 survey points in survey on 1997-09-18 00:00:00
# Mean elevations -4.39
# 64 survey points in survey on 1997-09-22 00:00:00
# Mean elevations 5.35
# 754 survey points in survey on 1997-09-23 00:00:00
# Mean elevations -2.75
# 757 survey points in survey on 1997-09-24 00:00:00
# Mean elevations -2.77
# 711 survey points in survey on 1997-09-25 00:00:00
# Mean elevations -2.69
# 742 survey points in survey on 1997-09-26 00:00:00
# Mean elevations -2.72
# 737 survey points in survey on 1997-09-27 00:00:00
# Mean elevations -2.67
# 683 survey points in survey on 1997-09-28 00:00:00
# Mean elevations -2.67
# 781 survey points in survey on 1997-09-29 00:00:00
# Mean elevations -2.76
# 687 survey points in survey on 1997-09-30 00:00:00
# Mean elevations -2.65
# 674 survey points in survey on 1997-10-01 00:00:00
# Mean elevations -3.51
# 64 survey points in survey on 1997-10-02 00:00:00
# Mean elevations 5.35
# 726 survey points in survey on 1997-10-03 00:00:00
# Mean elevations -2.71
# 672 survey points in survey on 1997-10-04 00:00:00
# Mean elevations -2.64
# 630 survey points in survey on 1997-10-05 00:00:00
# Mean elevations -3.50
# 64 survey points in survey on 1997-10-06 00:00:00
# Mean elevations 5.35
# 754 survey points in survey on 1997-10-07 00:00:00
# Mean elevations -2.75
# 672 survey points in survey on 1997-10-08 00:00:00
# Mean elevations -2.64
# 724 survey points in survey on 1997-10-09 00:00:00
# Mean elevations -2.65
# 672 survey points in survey on 1997-10-10 00:00:00
# Mean elevations -2.69
# 722 survey points in survey on 1997-10-11 00:00:00
# Mean elevations -2.77
# 701 survey points in survey on 1997-10-12 00:00:00
# Mean elevations -2.66
# 673 survey points in survey on 1997-10-13 00:00:00
# Mean elevations -2.57
# 711 survey points in survey on 1997-10-14 00:00:00
# Mean elevations -2.74
# 691 survey points in survey on 1997-10-15 00:00:00
# Mean elevations -2.65
# 709 survey points in survey on 1997-10-16 00:00:00
# Mean elevations -2.67
# 732 survey points in survey on 1997-10-17 00:00:00
# Mean elevations -2.76
# 612 survey points in survey on 1997-10-18 00:00:00
# Mean elevations -1.92
# 621 survey points in survey on 1997-10-19 00:00:00
# Mean elevations -3.47
# 64 survey points in survey on 1997-10-21 00:00:00
# Mean elevations 5.35
# 704 survey points in survey on 1997-10-22 00:00:00
# Mean elevations -2.66
# 664 survey points in survey on 1997-10-23 00:00:00
# Mean elevations -3.48
# 767 survey points in survey on 1997-10-24 00:00:00
# Mean elevations -1.98
# 671 survey points in survey on 1997-10-25 00:00:00
# Mean elevations -2.63
# 1163 survey points in survey on 1997-10-26 00:00:00
# Mean elevations -4.38
# 735 survey points in survey on 1997-10-27 00:00:00
# Mean elevations -2.68
# 658 survey points in survey on 1997-10-28 00:00:00
# Mean elevations -2.59
# 722 survey points in survey on 1997-10-29 00:00:00
# Mean elevations -2.57
# 693 survey points in survey on 1997-10-30 00:00:00
# Mean elevations -2.62
# 625 survey points in survey on 1997-10-31 00:00:00
# Mean elevations -3.56
# 64 survey points in survey on 1997-12-01 00:00:00
# Mean elevations 5.35
# 599 survey points in survey on 1997-12-02 00:00:00
# Mean elevations -2.99
# 65 survey points in survey on 1997-12-17 00:00:00
# Mean elevations 5.31
# 997 survey points in survey on 1997-12-18 00:00:00
# Mean elevations -4.47
# 63 survey points in survey on 1998-01-12 00:00:00
# Mean elevations 5.38
# 1123 survey points in survey on 1998-01-13 00:00:00
# Mean elevations -4.59
# 64 survey points in survey on 1998-01-27 00:00:00
# Mean elevations 5.35
# 1133 survey points in survey on 1998-01-28 00:00:00
# Mean elevations -4.63
# 64 survey points in survey on 1998-02-12 00:00:00
# Mean elevations 5.35
# 1132 survey points in survey on 1998-02-13 00:00:00
# Mean elevations -4.45
# 64 survey points in survey on 1998-02-26 00:00:00
# Mean elevations 5.35
# 1113 survey points in survey on 1998-02-27 00:00:00
# Mean elevations -4.40
# 64 survey points in survey on 1998-03-17 00:00:00
# Mean elevations 5.35
# 1128 survey points in survey on 1998-03-18 00:00:00
# Mean elevations -4.51
# 64 survey points in survey on 1998-03-30 00:00:00
# Mean elevations 5.35
# 1100 survey points in survey on 1998-03-31 00:00:00
# Mean elevations -4.53
# 64 survey points in survey on 1998-04-17 00:00:00
# Mean elevations 5.35
# 1092 survey points in survey on 1998-04-18 00:00:00
# Mean elevations -4.43
# 64 survey points in survey on 1998-05-18 00:00:00
# Mean elevations 5.35
# 1124 survey points in survey on 1998-05-19 00:00:00
# Mean elevations -4.79
# 64 survey points in survey on 1998-06-17 00:00:00
# Mean elevations 5.35
# 1132 survey points in survey on 1998-06-18 00:00:00
# Mean elevations -4.78
# 64 survey points in survey on 1998-07-14 00:00:00
# Mean elevations 5.35
# 1054 survey points in survey on 1998-07-15 00:00:00
# Mean elevations -4.61
# 64 survey points in survey on 1998-07-31 00:00:00
# Mean elevations 5.35
# 1018 survey points in survey on 1998-08-01 00:00:00
# Mean elevations -4.57
# 64 survey points in survey on 1998-08-13 00:00:00
# Mean elevations 5.35
# 821 survey points in survey on 1998-08-14 00:00:00
# Mean elevations -4.11
# 1113 survey points in survey on 1998-08-25 00:00:00
# Mean elevations -4.39
# 1099 survey points in survey on 1998-08-30 00:00:00
# Mean elevations -4.30
# 63 survey points in survey on 1998-09-15 00:00:00
# Mean elevations 5.38
# 1105 survey points in survey on 1998-09-16 00:00:00
# Mean elevations -4.94
# 63 survey points in survey on 1998-09-29 00:00:00
# Mean elevations 5.38
# 417 survey points in survey on 1998-09-30 00:00:00
# Mean elevations -2.43
# 63 survey points in survey on 1998-10-05 00:00:00
# Mean elevations 5.38
# 417 survey points in survey on 1998-10-06 00:00:00
# Mean elevations -2.49
# 63 survey points in survey on 1998-10-15 00:00:00
# Mean elevations 5.38
# 433 survey points in survey on 1998-10-16 00:00:00
# Mean elevations -2.48
# 47 survey points in survey on 1998-10-26 00:00:00
# Mean elevations 5.20
# 998 survey points in survey on 1998-10-27 00:00:00
# Mean elevations -4.73
# 47 survey points in survey on 1998-11-10 00:00:00
# Mean elevations 5.20
# 213 survey points in survey on 1998-11-11 00:00:00
# Mean elevations -4.51
# 923 survey points in survey on 1998-11-25 00:00:00
# Mean elevations -3.81
# 47 survey points in survey on 1998-12-22 00:00:00
# Mean elevations 5.20
# 1058 survey points in survey on 1998-12-23 00:00:00
# Mean elevations -4.88
# 47 survey points in survey on 1999-01-12 00:00:00
# Mean elevations 5.20
# 785 survey points in survey on 1999-01-13 00:00:00
# Mean elevations -4.02
# 47 survey points in survey on 1999-01-27 00:00:00
# Mean elevations 5.20
# 847 survey points in survey on 1999-01-28 00:00:00
# Mean elevations -4.30
# 47 survey points in survey on 1999-02-08 00:00:00
# Mean elevations 5.20
# 812 survey points in survey on 1999-02-09 00:00:00
# Mean elevations -4.26
# 47 survey points in survey on 1999-03-01 00:00:00
# Mean elevations 5.20
# 897 survey points in survey on 1999-03-02 00:00:00
# Mean elevations -4.18
# 47 survey points in survey on 1999-03-23 00:00:00
# Mean elevations 5.20
# 725 survey points in survey on 1999-03-24 00:00:00
# Mean elevations -4.52
# 47 survey points in survey on 1999-03-31 00:00:00
# Mean elevations 5.20
# 832 survey points in survey on 1999-04-01 00:00:00
# Mean elevations -4.27
# 47 survey points in survey on 1999-04-19 00:00:00
# ...
# Mean elevations -4.17
# 6 survey points in survey on 2002-04-17 00:00:00
# Mean elevations 5.07
# 1008 survey points in survey on 2002-04-18 00:00:00
# Mean elevations -4.17
# 6 survey points in survey on 2002-05-07 00:00:00
# Mean elevations 5.07
# 1052 survey points in survey on 2002-05-08 00:00:00
# Mean elevations -4.21
# 7 survey points in survey on 2002-05-29 00:00:00
# Mean elevations 4.70
# 997 survey points in survey on 2002-05-30 00:00:00
# Mean elevations -4.16
# 6 survey points in survey on 2002-06-11 00:00:00
# Mean elevations 5.07
# 1031 survey points in survey on 2002-06-12 00:00:00
# Mean elevations -4.22
# 5 survey points in survey on 2002-06-28 00:00:00
# Mean elevations 4.95
# 1003 survey points in survey on 2002-06-29 00:00:00
# Mean elevations -4.51
# 11 survey points in survey on 2002-07-16 00:00:00
# Mean elevations 3.85
# 1037 survey points in survey on 2002-07-17 00:00:00
# Mean elevations -4.25
# 256 survey points in survey on 2002-08-16 00:00:00
# Mean elevations -7.61
# 7 survey points in survey on 2002-09-04 00:00:00
# Mean elevations 4.69
# 1176 survey points in survey on 2002-09-05 00:00:00
# Mean elevations -5.30
# 6 survey points in survey on 2002-10-23 00:00:00
# Mean elevations 5.07
# 985 survey points in survey on 2002-10-24 00:00:00
# Mean elevations -4.16
# 7 survey points in survey on 2002-11-25 00:00:00
# Mean elevations 4.73
# 1020 survey points in survey on 2002-11-26 00:00:00
# Mean elevations -4.20
# 6 survey points in survey on 2002-12-23 00:00:00
# Mean elevations 5.07
# 969 survey points in survey on 2002-12-24 00:00:00
# Mean elevations -4.53
# 6 survey points in survey on 2003-01-09 00:00:00
# Mean elevations 5.07
# 900 survey points in survey on 2003-01-10 00:00:00
# Mean elevations -4.59
# 6 survey points in survey on 2003-01-29 00:00:00
# Mean elevations 5.07
# 883 survey points in survey on 2003-01-30 00:00:00
# Mean elevations -4.34
# 6 survey points in survey on 2003-02-24 00:00:00
# Mean elevations 5.07
# 890 survey points in survey on 2003-02-25 00:00:00
# Mean elevations -4.24
# 449 survey points in survey on 2003-04-15 00:00:00
# Mean elevations -8.52
# 6 survey points in survey on 2003-04-30 00:00:00
# Mean elevations 5.07
# 1193 survey points in survey on 2003-05-01 00:00:00
# Mean elevations -5.14
# 6 survey points in survey on 2003-05-28 00:00:00
# Mean elevations 5.07
# 1102 survey points in survey on 2003-05-29 00:00:00
# Mean elevations -4.35
# 6 survey points in survey on 2003-06-12 00:00:00
# Mean elevations 5.07
# 962 survey points in survey on 2003-06-13 00:00:00
# Mean elevations -4.11
# 6 survey points in survey on 2003-06-25 00:00:00
# Mean elevations 5.07
# 856 survey points in survey on 2003-06-26 00:00:00
# Mean elevations -4.15
# 6 survey points in survey on 2003-07-09 00:00:00
# Mean elevations 5.07
# 925 survey points in survey on 2003-07-10 00:00:00
# Mean elevations -3.95
# 6 survey points in survey on 2003-08-08 00:00:00
# Mean elevations 5.07
# 237 survey points in survey on 2003-08-09 00:00:00
# Mean elevations -9.06
# 5 survey points in survey on 2003-08-26 00:00:00
# Mean elevations 4.95
# 783 survey points in survey on 2003-08-27 00:00:00
# Mean elevations -4.24
# 6 survey points in survey on 2003-09-14 00:00:00
# Mean elevations 5.07
# 442 survey points in survey on 2003-09-15 00:00:00
# Mean elevations -2.40
# 295 survey points in survey on 2003-09-22 00:00:00
# Mean elevations -8.01
# 874 survey points in survey on 2003-12-17 00:00:00
# Mean elevations -4.29
# 6 survey points in survey on 2004-01-08 00:00:00
# Mean elevations 5.18
# 284 survey points in survey on 2004-01-09 00:00:00
# Mean elevations -8.29
# 8 survey points in survey on 2004-01-29 00:00:00
# Mean elevations 4.82
# 129 survey points in survey on 2004-01-30 00:00:00
# Mean elevations -4.91
# 8 survey points in survey on 2004-02-23 00:00:00
# Mean elevations 4.82
# 1015 survey points in survey on 2004-02-24 00:00:00
# Mean elevations -4.85
# 7 survey points in survey on 2004-03-12 00:00:00
# Mean elevations 4.82
# 1118 survey points in survey on 2004-03-13 00:00:00
# Mean elevations -4.93
# 8 survey points in survey on 2004-03-24 00:00:00
# Mean elevations 4.82
# 1186 survey points in survey on 2004-03-25 00:00:00
# Mean elevations -5.38
# 63 survey points in survey on 2004-04-09 00:00:00
# Mean elevations -1.40
# 7 survey points in survey on 2004-04-27 00:00:00
# Mean elevations 4.82
# 1083 survey points in survey on 2004-04-28 00:00:00
# Mean elevations -5.47
# 7 survey points in survey on 2004-05-19 00:00:00
# Mean elevations 4.82
# 1188 survey points in survey on 2004-05-20 00:00:00
# Mean elevations -5.33
# 9 survey points in survey on 2004-06-16 00:00:00
# Mean elevations 4.28
# 1183 survey points in survey on 2004-06-17 00:00:00
# Mean elevations -4.95
# 1100 survey points in survey on 2004-07-08 00:00:00
# Mean elevations -5.52
# 622 survey points in survey on 2004-08-05 00:00:00
# Mean elevations -5.41
# 415 survey points in survey on 2004-09-30 00:00:00
# Mean elevations -5.89
# 7 survey points in survey on 2004-11-03 00:00:00
# Mean elevations 4.60
# 362 survey points in survey on 2004-11-04 00:00:00
# Mean elevations -6.42
# 581 survey points in survey on 2004-11-13 00:00:00
# Mean elevations -8.82
# 609 survey points in survey on 2004-11-20 00:00:00
# Mean elevations -8.68
# 4 survey points in survey on 2004-11-22 00:00:00
# Mean elevations 5.57
# 566 survey points in survey on 2004-11-23 00:00:00
# Mean elevations -8.58
# 7 survey points in survey on 2005-01-12 00:00:00
# Mean elevations 4.60
# 439 survey points in survey on 2005-01-13 00:00:00
# Mean elevations -8.38
# 602 survey points in survey on 2005-01-27 00:00:00
# Mean elevations -8.52
# 6 survey points in survey on 2005-02-10 00:00:00
# Mean elevations 4.89
# 528 survey points in survey on 2005-02-11 00:00:00
# Mean elevations -9.11
# 6 survey points in survey on 2005-03-16 00:00:00
# Mean elevations 3.66
# 571 survey points in survey on 2005-03-17 00:00:00
# Mean elevations -8.98
# 8 survey points in survey on 2005-04-20 00:00:00
# Mean elevations 4.33
# 475 survey points in survey on 2005-04-21 00:00:00
# Mean elevations -8.99
# 944 survey points in survey on 2005-06-10 00:00:00
# Mean elevations -4.64
# 15 survey points in survey on 2005-08-22 00:00:00
# Mean elevations 4.79
# 532 survey points in survey on 2005-08-23 00:00:00
# Mean elevations -8.64
# 532 survey points in survey on 2005-08-24 00:00:00
# Mean elevations -8.64
# 16 survey points in survey on 2005-09-01 00:00:00
# Mean elevations 4.65
# 513 survey points in survey on 2005-09-02 00:00:00
# Mean elevations -8.93
# 513 survey points in survey on 2005-09-03 00:00:00
# Mean elevations -8.93
# 11 survey points in survey on 2005-09-21 00:00:00
# Mean elevations 5.11
# 499 survey points in survey on 2005-09-22 00:00:00
# Mean elevations -8.87
# 489 survey points in survey on 2006-04-06 00:00:00
# Mean elevations -8.83
# 588 survey points in survey on 2006-07-07 00:00:00
# Mean elevations -8.36
# 36 survey points in survey on 2006-09-19 00:00:00
# Mean elevations 3.68
# 502 survey points in survey on 2006-09-20 00:00:00
# Mean elevations -8.72
# 29 survey points in survey on 2006-09-25 00:00:00
# Mean elevations 3.98
# 504 survey points in survey on 2006-09-26 00:00:00
# Mean elevations -9.02
# 574 survey points in survey on 2007-04-28 00:00:00
# Mean elevations -8.05
# 40 survey points in survey on 2007-05-11 00:00:00
# Mean elevations 3.76
# 522 survey points in survey on 2007-05-12 00:00:00
# Mean elevations -8.89
# 646 survey points in survey on 2008-01-08 00:00:00
# Mean elevations -6.21
# 713 survey points in survey on 2008-02-21 00:00:00
# Mean elevations -6.91
# 1256 survey points in survey on 2008-04-12 00:00:00
# Mean elevations -5.22
# 563 survey points in survey on 2008-05-20 00:00:00
# Mean elevations -8.48
# 531 survey points in survey on 2008-06-25 00:00:00
# Mean elevations -7.84
# 590 survey points in survey on 2008-08-06 00:00:00
# Mean elevations -7.93
# 549 survey points in survey on 2008-09-16 00:00:00
# Mean elevations -9.85
# 35 survey points in survey on 2008-09-30 00:00:00
# Mean elevations 4.94
# 526 survey points in survey on 2008-10-01 00:00:00
# Mean elevations -9.26
# 579 survey points in survey on 2008-10-30 00:00:00
# Mean elevations -9.16
# 501 survey points in survey on 2008-11-10 00:00:00
# Mean elevations -8.63
# 529 survey points in survey on 2009-01-06 00:00:00
# Mean elevations -8.91
# 400 survey points in survey on 2009-05-05 00:00:00
# Mean elevations -5.95
# 579 survey points in survey on 2009-07-03 00:00:00
# Mean elevations -4.29
# 391 survey points in survey on 2009-08-07 00:00:00
# Mean elevations -3.00
# 587 survey points in survey on 2009-08-12 00:00:00
# Mean elevations -8.76
# 522 survey points in survey on 2009-08-19 00:00:00
# Mean elevations -8.53
# 1142 survey points in survey on 2009-09-17 00:00:00
# Mean elevations -9.62
# 839 survey points in survey on 2009-12-11 00:00:00
# Mean elevations -8.71
# 540 survey points in survey on 2010-02-23 00:00:00
# Mean elevations -8.94
# 1710 survey points in survey on 2010-06-05 00:00:00
# Mean elevations -9.01
# 1482 survey points in survey on 2010-07-29 00:00:00
# Mean elevations -9.23
# 512 survey points in survey on 2010-11-23 00:00:00
# Mean elevations -8.91
# 531 survey points in survey on 2011-02-08 00:00:00
# Mean elevations -8.90
# 542 survey points in survey on 2011-03-19 00:00:00
# Mean elevations -8.75
# 545 survey points in survey on 2011-05-03 00:00:00
# Mean elevations -8.42
# 732 survey points in survey on 2011-05-17 00:00:00
# Mean elevations -5.12
# 546 survey points in survey on 2011-06-07 00:00:00
# Mean elevations -8.81
# 561 survey points in survey on 2011-07-12 00:00:00
# Mean elevations -9.13
# 433 survey points in survey on 2011-08-23 00:00:00
# Mean elevations -8.30
# 602 survey points in survey on 2011-08-30 00:00:00
# Mean elevations -8.84
# 915 survey points in survey on 2011-09-13 00:00:00
# Mean elevations -6.74
# 766 survey points in survey on 2011-10-18 00:00:00
# Mean elevations -8.77
# 567 survey points in survey on 2011-11-17 00:00:00
# Mean elevations -8.90
# 521 survey points in survey on 2011-12-24 00:00:00
# Mean elevations -8.67
# 498 survey points in survey on 2012-02-15 00:00:00
# Mean elevations -8.61
# 546 survey points in survey on 2012-03-17 00:00:00
# Mean elevations -8.72
# 529 survey points in survey on 2012-06-14 00:00:00
# Mean elevations -8.88
# 582 survey points in survey on 2012-06-28 00:00:00
# Mean elevations -8.85
# 780 survey points in survey on 2012-08-11 00:00:00
# Mean elevations -8.62
# 835 survey points in survey on 2012-09-29 00:00:00
# Mean elevations -9.27
# 816 survey points in survey on 2012-10-26 00:00:00
# Mean elevations -9.14
# 277 survey points in survey on 2012-11-02 00:00:00
# Mean elevations -8.58
# 817 survey points in survey on 2012-11-28 00:00:00
# Mean elevations -8.60
# 504 survey points in survey on 2012-12-20 00:00:00
# Mean elevations -8.94
# 516 survey points in survey on 2013-02-06 00:00:00
# Mean elevations -9.02
# 544 survey points in survey on 2013-04-10 00:00:00
# Mean elevations -9.05
# 511 survey points in survey on 2013-05-23 00:00:00
# Mean elevations -8.82
# 608 survey points in survey on 2013-07-03 00:00:00
# Mean elevations -9.19
# 454 survey points in survey on 2013-08-14 00:00:00
# Mean elevations -8.57
# 536 survey points in survey on 2013-09-06 00:00:00
# Mean elevations -8.93
# 517 survey points in survey on 2013-10-24 00:00:00
# Mean elevations -9.04
# 527 survey points in survey on 2013-12-06 00:00:00
# Mean elevations -9.01
# 316 survey points in survey on 2014-01-28 00:00:00
# Mean elevations -6.60
# 535 survey points in survey on 2014-03-15 00:00:00
# Mean elevations -8.91
# 570 survey points in survey on 2014-05-08 00:00:00
# Mean elevations -9.01
# 548 survey points in survey on 2014-07-25 00:00:00
# Mean elevations -8.61
# 573 survey points in survey on 2014-09-06 00:00:00
# Mean elevations -8.80
# 480 survey points in survey on 2014-10-01 00:00:00
# Mean elevations -6.37
# 547 survey points in survey on 2014-10-28 00:00:00
# Mean elevations -8.72
# 506 survey points in survey on 2014-12-13 00:00:00
# Mean elevations -9.02
# 1130 survey points in survey on 2015-02-03 00:00:00
# Mean elevations -5.09
# 600 survey points in survey on 2015-03-18 00:00:00
# Mean elevations -9.12
# 1147 survey points in survey on 2015-04-14 00:00:00
# Mean elevations -8.92
# 763 survey points in survey on 2015-04-29 00:00:00
# Mean elevations -8.87
# 851 survey points in survey on 2015-04-30 00:00:00
# Mean elevations -9.23
# 542 survey points in survey on 2015-05-20 00:00:00
# Mean elevations -8.72
# 852 survey points in survey on 2015-06-19 00:00:00
# Mean elevations -9.17
# 569 survey points in survey on 2015-08-08 00:00:00
# Mean elevations -8.74
# 513 survey points in survey on 2015-09-16 00:00:00
# Mean elevations -9.00
# 1130 survey points in survey on 2015-10-15 00:00:00
# Mean elevations -8.86
# 5 survey points in survey on 2015-10-21 00:00:00
# Mean elevations 2.85
# 537 survey points in survey on 2015-10-22 00:00:00
# Mean elevations -3.78
# 805 survey points in survey on 2015-11-17 00:00:00
# Mean elevations -9.07
# 1544 survey points in survey on 2015-12-22 00:00:00
# Mean elevations -9.00
# 781 survey points in survey on 2016-01-15 00:00:00
# Mean elevations -9.00
# 813 survey points in survey on 2016-03-11 00:00:00
# Mean elevations -8.87
# 870 survey points in survey on 2016-04-29 00:00:00
# Mean elevations -9.14
# 794 survey points in survey on 2016-05-28 00:00:00
# Mean elevations -9.09
# 801 survey points in survey on 2016-06-29 00:00:00
# Mean elevations -9.13
# 789 survey points in survey on 2016-07-27 00:00:00
# Mean elevations -8.97
# 1522 survey points in survey on 2016-08-18 00:00:00
# Mean elevations -9.18
# 777 survey points in survey on 2016-09-09 00:00:00
# Mean elevations -9.14
# 1056 survey points in survey on 2016-10-04 00:00:00
# Mean elevations -9.05
# 1624 survey points in survey on 2016-10-21 00:00:00
# Mean elevations -9.17
# 1516 survey points in survey on 2016-11-04 00:00:00
# Mean elevations -9.04
# 1532 survey points in survey on 2016-11-17 00:00:00
# Mean elevations -8.98
# 1554 survey points in survey on 2017-01-06 00:00:00
# Mean elevations -9.18
# 868 survey points in survey on 2017-01-28 00:00:00
# Mean elevations -9.18
# 832 survey points in survey on 2017-02-28 00:00:00
# Mean elevations -9.02
# 866 survey points in survey on 2017-03-28 00:00:00
# Mean elevations -9.21
# 955 survey points in survey on 2017-04-12 00:00:00
# Mean elevations -9.15
# 761 survey points in survey on 2017-05-19 00:00:00
# Mean elevations -9.15
# 860 survey points in survey on 2017-06-07 00:00:00
# Mean elevations -9.13
# 779 survey points in survey on 2017-06-14 00:00:00
# Mean elevations -9.22
# 537 survey points in survey on 2017-06-22 00:00:00
# Mean elevations -7.80
# 659 survey points in survey on 2017-07-08 00:00:00
# Mean elevations -8.61
# 719 survey points in survey on 2017-09-06 00:00:00
# Mean elevations -9.01
# 703 survey points in survey on 2017-10-12 00:00:00
# Mean elevations -9.09
# 914 survey points in survey on 2017-10-27 00:00:00
# Mean elevations -2.23
# 706 survey points in survey on 2017-11-22 00:00:00
# Mean elevations -9.05
# 706 survey points in survey on 2017-12-12 00:00:00
# Mean elevations -9.16
# 851 survey points in survey on 2018-02-27 00:00:00
# Mean elevations -9.14
# 914 survey points in survey on 2018-03-16 00:00:00
# Mean elevations -9.34
# 1598 survey points in survey on 2018-04-19 00:00:00
# Mean elevations -9.27
# 738 survey points in survey on 2018-05-24 00:00:00
# Mean elevations -9.01
# 737 survey points in survey on 2018-06-19 00:00:00
# Mean elevations -9.35
# 801 survey points in survey on 2018-07-21 00:00:00
# Mean elevations -8.86
# 845 survey points in survey on 2018-08-15 00:00:00
# Mean elevations -9.27
# 888 survey points in survey on 2018-09-20 00:00:00
# Mean elevations -8.58
# 875 survey points in survey on 2018-10-18 00:00:00
# Mean elevations -9.01
# 544 survey points in survey on 2018-11-21 00:00:00
# Mean elevations -8.64
# 897 survey points in survey on 2018-12-14 00:00:00
# Mean elevations -8.10
# 916 survey points in survey on 2019-02-02 00:00:00
# Mean elevations -9.31
# 923 survey points in survey on 2019-02-16 00:00:00
# Mean elevations -9.00
# 770 survey points in survey on 2019-03-26 00:00:00
# Mean elevations -9.10
# 389 survey points in survey on 2019-04-12 00:00:00
# Mean elevations -4.45
# 768 survey points in survey on 2019-04-18 00:00:00
# Mean elevations -8.98
# 757 survey points in survey on 2019-05-21 00:00:00
# Mean elevations -8.95
# 944 survey points in survey on 2019-06-26 00:00:00
# Mean elevations -8.86
# 805 survey points in survey on 2019-07-17 00:00:00
# Mean elevations -8.79

# %%
plt.figure(figsize=(18,6))
plt.pcolormesh(xOut, nc.num2date(tOut, 'seconds since 1970-01-01'), zOutNorth)# , cmap='RdBu', norm=(MidpointNormalize(midpoint=0)))
plt.colorbar()
# notice bar migration patterns
